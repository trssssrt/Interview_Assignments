# %% [markdown]
# # Prompt
# The programming problem that we would like you to take on is to write a program that identifies the areas of light in sample TIFF images from a digital microscope.
#
# To give you some context. Our microscopes acquire images as bitmaps. Each bitmap has a number light spots that look like circular smudges. These are generated by the light emitted from the florescent molecules that are within the sample, hitting the detector. The first part of super resolution microscopy is to locate these smudges.
#
# The input to your code should be a TIFF image. The images have some noise (this is normal). You can assume that each smudge is 6x6 pixels. You should be able to run your code and output a list of rectangles that bound the smudges that you have detected. Your code should be resilient to the noise and any artifacts that appear in the image and find only the circular smudges. The programming problem should take you no more than two or three evenings. Your code should be clean, efficient, and of a quality that you feel would be suitable to be production code. There are 3rd party libraries, system utilities etc available that you can use to read TIFF images so don’t write your own TIFF reader ;-)
#
# Looking at the images will give you an intuitive idea of the noise that you will encounter in the image. The background of the image is not uniform but appears "mottled", occasionally there are single stray pixels that are very bright. Additionally the smudges themselves are not at all uniform but are themselves subject to noise (you will see that they are somewhat mottled). If you consider the frame as a whole, athough the light smudges which we are identifying are very visible (easy to spot with the naked eye) statistically they contribute very little to the overall brightness of the image.
#
# For this challenge we are not concerned about user interface (a command line tool is fine), or how you read the images you can use whatever library or frameworks that you want - however we would like you to write the code that processes the bitmap image and discovers the positions of the smudges yourself.
#
# If you have any questions just drop us an email.
#
# We supply a few of test images that we would like your program to work with.
#
# Finally we would like you to submit clean, simple, well-structured code that you would consider ready for submission to a professional project.

# %%
# import the necessary packages
import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# Constants
blur_size = (5, 5)
showPlots = False

# %%
# import images
path = 'images/'
fileType = '.tif'
images = [(cv2.imread(file), file) for file in glob.glob(path + "*" + fileType)]
# images = [(cv2.imread(file), file) for file in glob.glob(path + "*.tif")]

# %%
imgs = []
for img in images:
    gray = cv2.cvtColor(img[0], cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, blur_size, 0)
    # threshold the image to reveal light regions in the
    # blurred image
#     thresh = cv2.threshold(blurred, 5, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.adaptiveThreshold(blurred,
                                   255,
#                                    cv2.ADAPTIVE_THRESH_MEAN_C,
                                   cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                   cv2.THRESH_BINARY,
                                   35,
                                   0
                                  )
    imgs.append(thresh)
    if showPlots:
        plt.imshow(thresh)#, cmap = 'gray', interpolation = 'bicubic')
        plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
        plt.title(img[1][len(path):-len(fileType)])
        plt.show()

# %%
import time
imgs = []
for img in images:
    gray = cv2.cvtColor(img[0], cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, blur_size, 0)
    # threshold the image to reveal light regions in the
    # blurred image
#     thresh = cv2.threshold(blurred, 5, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.adaptiveThreshold(blurred,
                                   255,
#                                    cv2.ADAPTIVE_THRESH_MEAN_C,
                                   cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                   cv2.THRESH_BINARY,
                                   35,
                                   0
                                  )
    imgs.append(thresh)
print('Thresh Complete\n')
for i in range(len(imgs)):
    print(images[i][1][len(path):-len(fileType)])
#     plt.imshow(imgs[i])#, cmap = 'gray', interpolation = 'bicubic')
#     plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
#     plt.title(images[i][1][len(path):-len(fileType)])
#     plt.show()
    # Apply hough transform on the image
    circles = cv2.HoughCircles(imgs[i],
                               cv2.HOUGH_GRADIENT,
                               1,
                               6,
#                                imgs[i].shape[0]/64,
                               param1=200,
                               param2=10,
#                                param1=200,
#                                param2=10,
                               minRadius=6,
#                                minRadius=5,
#                                maxRadius=30
                              )
    # Draw detected circles
    if circles is not None:
#         print(circles)
        circles = np.uint16(np.around(circles))
        for j in circles[0, :]:
            # Draw outer circle
            cv2.circle(imgs[i],
                       (j[0], j[1]),
                       j[2],
                       (0, 255, 0),
                       2
                      )
#             # Draw inner circle
#             cv2.circle(imgs[i], (j[0], j[1]), 2, (0, 0, 255), 3)
    
    plt.imshow(imgs[i])#, cmap = 'gray', interpolation = 'bicubic')
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.title(images[i][1][len(path):-len(fileType)] + '_circles')
    plt.show()
#     time.sleep(60)   # Delays for 5 seconds. You can also use a float value.
print('Complete')
# Out:
# Thresh Complete
#
# coins
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-d10eb32480eb> in <module>
#      33 #                                param1=200,
#      34 #                                param2=10,
# ---> 35                                minRadius=6,
#      36 #                                minRadius=5,
#      37 #                                maxRadius=30
#
# KeyboardInterrupt:

# %%
import time
imgs = []
for img in images:
    gray = cv2.cvtColor(img[0], cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, blur_size, 0)
    # threshold the image to reveal light regions in the
    # blurred image
#     thresh = cv2.threshold(blurred, 5, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.adaptiveThreshold(blurred,
                                   255,
#                                    cv2.ADAPTIVE_THRESH_MEAN_C,
                                   cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                   cv2.THRESH_BINARY,
                                   35,
                                   0
                                  )
    imgs.append(thresh)
print('Thresh Complete\n')
for i in range(len(imgs)):
    print(images[i][1][len(path):-len(fileType)])
#     plt.imshow(imgs[i])#, cmap = 'gray', interpolation = 'bicubic')
#     plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
#     plt.title(images[i][1][len(path):-len(fileType)])
#     plt.show()
    # Apply hough transform on the image
    circles = cv2.HoughCircles(imgs[i],
                               cv2.HOUGH_GRADIENT,
                               1,
                               6,
#                                imgs[i].shape[0]/64,
                               param1=200,
                               param2=10,
#                                param1=200,
#                                param2=10,
                               minRadius=6,
#                                minRadius=5,
#                                maxRadius=30
                              )
    # Draw detected circles
    if circles is not None:
#         print(circles)
        circles = np.uint16(np.around(circles))
        for j in circles[0, :]:
            # Draw outer circle
            cv2.circle(imgs[i],
                       (j[0], j[1]),
                       j[2],
                       (0, 255, 0),
                       2
                      )
#             # Draw inner circle
#             cv2.circle(imgs[i], (j[0], j[1]), 2, (0, 0, 255), 3)

    plt.imshow(imgs[i])#, cmap = 'gray', interpolation = 'bicubic')
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.title(images[i][1][len(path):-len(fileType)] + '_circles')
    plt.show()
#     time.sleep(60)   # Delays for 5 seconds. You can also use a float value.
print('Complete')
# Out:
# Thresh Complete
#
# coins
# U8grK
# Complete

# %%
import time
imgs = []
for img in images:
    gray = cv2.cvtColor(img[0], cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, blur_size, 0)
    # threshold the image to reveal light regions in the
    # blurred image
#     thresh = cv2.threshold(blurred, 5, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.adaptiveThreshold(blurred,
                                   255,
#                                    cv2.ADAPTIVE_THRESH_MEAN_C,
                                   cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                   cv2.THRESH_BINARY,
                                   35,
                                   0
                                  )
    imgs.append(thresh)
print('Thresh Complete\n')
for k in range(30, 200, 15):
    for p in range(15, int(k / 2), 15):
        for i in range(len(imgs)):
            print(str(images[i][1][len(path):-len(fileType)]) + '({},{})'.format(k, p))
        #     plt.imshow(imgs[i])#, cmap = 'gray', interpolation = 'bicubic')
        #     plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
        #     plt.title(images[i][1][len(path):-len(fileType)])
        #     plt.show()
            # Apply hough transform on the image
            circles = cv2.HoughCircles(imgs[i],
                                       cv2.HOUGH_GRADIENT,
                                       1,
#                                        minDist = 6,
                                       minDist = imgs[i].shape[0]/64,
                                       param1 = int(k),
                                       param2 = int(p),
        #                                param1=200,
        #                                param2=10,
                                       minRadius=6,
        #                                minRadius=5,
        #                                maxRadius=30
                                      )
            # Draw detected circles
            if circles is not None:
                print(circles[0].shape)
                circles = np.uint16(np.around(circles))
                for j in circles[0, :]:
                    # Draw outer circle
                    cv2.circle(imgs[i],
                               (j[0], j[1]),
                               j[2],
                               (0, 255, 0),
                               2
                              )
        #             # Draw inner circle
        #             cv2.circle(imgs[i], (j[0], j[1]), 2, (0, 0, 255), 3)

#             plt.imshow(imgs[i])#, cmap = 'gray', interpolation = 'bicubic')
#             plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
#             plt.title(images[i][1][len(path):-len(fileType)] + '_circles--' + '({},{})'.format(k, p))
#             plt.show()
            
        #     time.sleep(60)   # Delays for 5 seconds. You can also use a float value.
        time.sleep(5)   # Delays for 5 seconds. You can also use a float value.
    time.sleep(60)   # Delays for 5 seconds. You can also use a float value.
print('Complete')
# Out:
# Thresh Complete

# %%
print(circles.shape)
canvas = np.ones((1000, 1000, 3), dtype=np.uint8) * 255
CIRCLE_RADIUS = 10
CIRCLE_THICKNESS = 2
COLOR_RED = (0, 0, 255)
for c in circles[0, :]:
    o_c = (int(c[0]), int(c[1]))
    cv2.circle(canvas, o_c, CIRCLE_RADIUS, COLOR_RED, CIRCLE_THICKNESS)

plt.imshow(canvas)
# Out:
# (1, 4825, 3)

# %%
plt.imshow(images[0][0])
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
plt.imshow(images[1][0])
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
plt.imshow(blurred, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
for image in images:
    gray = cv2.cvtColor(image[0], cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, blur_size, 0)
    plt.imshow(blurred)#, cmap = 'gray', interpolation = 'bicubic')
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.title(image[1][len(path):])
    plt.show()

# %% [markdown]
# ## Adding circles around circular regions of importance

# %%
gray = cv2.cvtColor(images[1][0], cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, blur_size, 0)
for i in (3):#range(1,10):
    # detect circles in the image
    circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT, i, 1)
    # ensure at least some circles were found
    if circles is not None:
        print(i)
        # convert the (x, y) coordinates and radius of the circles to integers
        circles = np.round(circles[0, :]).astype("int")

        # loop over the (x, y) coordinates and radius of the circles
        for (x, y, r) in circles:
            # draw the circle in the output image, then draw a rectangle
            # corresponding to the center of the circle
            cv2.circle(gray, (x, y), r, (0, 255, 0), 4)

    #     # show the output image
    #     cv2.imshow("output", np.hstack([image, output]))
    #     cv2.waitKey(0)
            plt.imshow(gray)
#             plt.imshow(np.hstack([images[0], output]))
            plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
            plt.show()
    else:
        print(circles)
